# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 =  pd.read_csv('/media/homes/farjad/repos/temp_repos/pair_dcmha/withDCMHA.csv')
df2 =  pd.read_csv('/media/homes/farjad/repos/temp_repos/pair_dcmha/withoutDCMHA.csv')

# %%
list(df1.columns)
# Out:
# ['Unnamed: 0',
#  'Step',
#  'encoder.layers.0.self_attn.attn._W_query.weight',
#  'encoder.layers.0.self_attn.attn._W_query.bias',
#  'encoder.layers.0.self_attn.attn._W_key.weight',
#  'encoder.layers.0.self_attn.attn._W_key.bias',
#  'encoder.layers.0.self_attn.attn._W_value.weight',
#  'encoder.layers.0.self_attn.attn._W_value.bias',
#  'encoder.layers.0.self_attn.attn._pre_compose_params.k1',
#  'encoder.layers.0.self_attn.attn._pre_compose_params.k2',
#  'encoder.layers.0.self_attn.attn._pre_compose_params.kg',
#  'encoder.layers.0.self_attn.attn._pre_compose_params.q1',
#  'encoder.layers.0.self_attn.attn._pre_compose_params.q2',
#  'encoder.layers.0.self_attn.attn._pre_compose_params.qg',
#  'encoder.layers.0.self_attn.attn._post_compose_params.k1',
#  'encoder.layers.0.self_attn.attn._post_compose_params.k2',
#  'encoder.layers.0.self_attn.attn._post_compose_params.kg',
#  'encoder.layers.0.self_attn.attn._post_compose_params.q1',
# ...

# %% [markdown]
# With DCMHA

# %%
col = 'encoder.layers.5.self_attn.attn._post_compose_params.qg'
# col = 'encoder.layers.2.self_attn.attn._pre_compose_params.k1'

plt.figure(figsize=(25, 10))
sns.lineplot(x='Step', y=col, data=df1, label=col, marker='o')
# sns.lineplot(x='time', y='incremental_cac', data=stuff_t, label='Use obs True', marker='o')
plt.xlabel('Steps')
plt.ylabel('Grad values')
plt.title('Gradients')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Without DCMHA

# %%
list(df2.columns)
# Out:
# ['Unnamed: 0',
#  'Step',
#  'encoder.layers.0.self_attn.in_proj_weight',
#  'encoder.layers.0.self_attn.in_proj_bias',
#  'encoder.layers.0.self_attn.out_proj.weight',
#  'encoder.layers.0.self_attn.out_proj.bias',
#  'encoder.layers.0.linear1.weight',
#  'encoder.layers.0.linear1.bias',
#  'encoder.layers.0.linear2.weight',
#  'encoder.layers.0.linear2.bias',
#  'encoder.layers.0.norm1.weight',
#  'encoder.layers.0.norm1.bias',
#  'encoder.layers.0.norm2.weight',
#  'encoder.layers.0.norm2.bias',
#  'encoder.layers.1.self_attn.in_proj_weight',
#  'encoder.layers.1.self_attn.in_proj_bias',
#  'encoder.layers.1.self_attn.out_proj.weight',
#  'encoder.layers.1.self_attn.out_proj.bias',
#  'encoder.layers.1.linear1.weight',
#  'encoder.layers.1.linear1.bias',
#  'encoder.layers.1.linear2.weight',
#  'encoder.layers.1.linear2.bias',
#  'encoder.layers.1.norm1.weight',
#  'encoder.layers.1.norm1.bias',
#  'encoder.layers.1.norm2.weight',
#  'encoder.layers.1.norm2.bias',
# ...

# %%
col = 'encoder.layers.5.self_attn.out_proj.weight'
# col = 'encoder.layers.5.self_attn.out_proj.weight'
# col = 'encoder.layers.2.self_attn.attn._pre_compose_params.k1'

plt.figure(figsize=(25, 10))
sns.lineplot(x='Step', y=col, data=df2, label=col, marker='o')
# sns.lineplot(x='time', y='incremental_cac', data=stuff_t, label='Use obs True', marker='o')
plt.xlabel('Steps')
plt.ylabel('Grad values')
plt.title('Gradients')
plt.legend()
plt.xticks(rotation=90)
plt.show()
